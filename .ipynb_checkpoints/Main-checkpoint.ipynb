# %% [markdown]
# # Memes V/s Notes

# %%
# importing stuff
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as functions
import matplotlib.pyplot as plt
if torch.cuda.is_available():
    print('device available')
    device = torch.device('cuda')
else:
    print('device unavailable')
    device = None
# Out:
# device available

# %% [markdown]
# ## Loading and Visualizing Data

# %%
X = np.load('Data/MVN_X.npy')
Y = np.load('Data/MVN_Y.npy')
print(Y[:10])
# Out:
# [0. 1. 0. 0. 0. 1. 0. 1. 0. 1.]

# %%
plt.imshow(X[4,:,:,::-1]) #cross-checking

# %%
X_test = X[1500:1600]
Y_test = Y[1500:1600]
print(X_test.shape)
print(Y_test[:10])
# Out:
# (100, 256, 256, 3)
# [1. 0. 1. 1. 0. 1. 1. 0. 0. 0.]

# %%
plt.imshow(X_test[4,:,:,::-1]) #cross-checking

# %%
X = X[:1500]
Y = Y[:1500]
print(X.shape)
print(Y.shape)
# Out:
# (1500, 256, 256, 3)
# (1500,)

# %%
# converting all to float and normalizing
X = (X.astype(float))/255
Y = (Y.astype(float))
X_test = (X_test.astype(float))/255
Y_test = (Y_test.astype(float))
X = np.transpose(X,(0,3,1,2)) #converting to pytorch format
X_test = np.transpose(X_test,(0,3,1,2))
print(X_test.shape)
# Out:
# (100, 3, 256, 256)

# %%
plt.imshow(X[2,0,:,:])

# %%
X = torch.from_numpy(X)
Y = torch.from_numpy(Y)
print(type(X))
print(type(Y))
# Out:
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>

# %% [markdown]
# ## Model Building

# %%
#MVN2
class MVNNet(nn.Module):
  def __init__(self):
    super(MVNNet,self).__init__()
    self.conv1 = nn.Conv2d(3,96,(11,11),stride=(4,4))
    self.conv2 = nn.Conv2d(96,134,(5,5),stride=(4,4))
    self.conv3 = nn.Conv2d(134,158,(3,3))
    self.fc1 = nn.Linear(158*2*2,252)
    self.fc2 = nn.Linear(252,1)

  def forward(self,x):
    x = functions.relu(self.conv1(x))
    x = functions.relu(self.conv2(x))
    x = functions.max_pool2d(x,(2,2))
    x = functions.relu(self.conv3(x))
    x = functions.max_pool2d(x,(2,2))
    x = x.view(x.size(0),-1)
    x = functions.relu(self.fc1(x))
    x = self.fc2(x)
    return x

# %%
net = MVNNet().double()
net.to(device)
optimizer = optim.Adam(net.parameters(),lr=0.001)

# %%
total_size = X.size(0)
batchsize = 15
epochs = 3
cost_fn = nn.BCEWithLogitsLoss()
costs = []
epoch_costs = []
for i in range(epochs):
    for j in range(int(total_size/batchsize)):
        optimizer.zero_grad()
        X_minibatch = X[j*batchsize:(j+1)*batchsize].to(device)
        Y_minibatch = Y[j*batchsize:(j+1)*batchsize].to(device)
        output = net(X_minibatch)
        cost = cost_fn(output,Y_minibatch.view(batchsize,1))
        cost.backward()
        optimizer.step()
        costs.append(float(cost.item()))
        if(j%10 == 0):
            print(str(cost.item())+' at epoch '+str(i))
        if(j == 0):
            epoch_costs.append(cost.item())
        del output
        del X_minibatch
        del Y_minibatch
        del cost
        torch.cuda.empty_cache()
    print('epoch complete')
# Out:
# 0.693232830682569 at epoch 0
# 0.6715451722686794 at epoch 0
# 0.5756838842783008 at epoch 0
# 0.5209554513378418 at epoch 0
# 0.1567196510458165 at epoch 0
# 0.19455722100490253 at epoch 0
# 0.8183619054350031 at epoch 0
# 0.23202769925490555 at epoch 0
# 0.059739345514719086 at epoch 0
# 0.5222998815767084 at epoch 0
# epoch complete
# 0.3318931927580941 at epoch 1
# 0.30017759067130456 at epoch 1
# 1.247166713361092 at epoch 1
# 0.027814766189069372 at epoch 1
# 0.07969175660373501 at epoch 1
# 0.34370774512728014 at epoch 1
# 0.6395679182450056 at epoch 1
# 0.26421101528304847 at epoch 1
# 0.5883848122767839 at epoch 1
# 0.2642396737414029 at epoch 1
# epoch complete
# 0.10417428640070357 at epoch 2
# 0.5788601094030974 at epoch 2
# 1.593490678454952 at epoch 2
# 0.13646909119037967 at epoch 2
# 0.09834878317827402 at epoch 2
# 0.6255527292256098 at epoch 2
# 0.4036846299250097 at epoch 2
# 0.2188480315746051 at epoch 2
# 0.016430002981526894 at epoch 2
# 0.043113886785460666 at epoch 2
# epoch complete

# %%
print(len(costs))
print(costs[-1])
print(epoch_costs)
plt.plot(costs)
plt.ylabel('Cost')
plt.xlabel('Num Iterations')
plt.title('Cost per iteration')
# Out:
# 300
# 0.04529572934424308
# [0.693232830682569, 0.3318931927580941, 0.10417428640070357]
# Text(0.5, 1.0, 'Cost per iteration')

# %%
# saving
torch.save(net.state_dict(),'MVN2.pth')

# %%
# loading
net = MVNNet().double()
net.load_state_dict(torch.load('/content/drive/My Drive/Colab Notebooks/MVN2.pth'))
net.to(device)

# %%
torch.cuda.empty_cache()
with torch.no_grad():
    for j in range(int((1500/15))):
        train_results_temp = net(X[j*15:(j+1)*15].to(device))
        train_results_temp = nn.Sigmoid()(train_results_temp)
        train_results_temp = train_results_temp.cpu().numpy()
        train_results = train_results_temp if (j == 0) else np.concatenate((train_results,train_results_temp))
        del train_results_temp
    train_labels = Y.cpu().numpy()
print(train_results.shape)
print(train_labels.shape)
# Out:
# (1500, 1)
# (1500,)

# %%
print(train_results.shape)
train_results = np.squeeze(train_results)
print(train_results[:10])
# Out:
# (1500, 1)
# [1.60560436e-10 9.22219378e-01 1.47080644e-14 1.81957499e-09
#  6.37079344e-04 9.73593939e-01 1.53353572e-02 8.93033726e-01
#  2.11002309e-06 9.54408992e-01]

# %%
train_results = (train_results > 0.5).astype(float)
print(train_results[:10])
print('these are train labels')
print(train_labels[:10])
predictions = (train_results == Y.cpu().numpy()).astype(float)
accuracy = (np.sum(predictions))/(predictions.shape)
print(float(accuracy*100))
# Out:
# [0. 1. 0. 0. 0. 1. 0. 1. 0. 1.]
# these are train labels
# [0. 1. 0. 0. 0. 1. 0. 1. 0. 1.]
# 97.8

# %%
X_test = torch.from_numpy(X_test)

# %%
print(X_test.shape)
# Out:
# torch.Size([100, 3, 256, 256])

# %%
torch.cuda.empty_cache()
with torch.no_grad():
    for j in range(int(100/10)):
        test_results_temp = net(X_test[j*10:(j+1)*10].to(device))
        test_results_temp = nn.Sigmoid()(test_results_temp)
        test_results_temp = test_results_temp.cpu().numpy()
        test_results = test_results_temp if(j==0) else np.concatenate((test_results,test_results_temp))
        del test_results_temp
    #test_labels = Y_test.numpy()
test_results = np.squeeze(test_results)
print(test_results.shape)
print(Y_test.shape)
# Out:
# (100,)
# (100,)

# %%
test_results = (test_results > 0.5).astype(float)
print(test_results[:10])
print('these are train labels')
print(Y_test[:10])
predictions = (test_results == Y_test).astype(float)
accuracy = (np.sum(predictions))/(predictions.shape)
print(float(accuracy*100))
# Out:
# [1. 0. 1. 1. 0. 1. 1. 0. 0. 0.]
# these are train labels
# [1. 0. 1. 1. 0. 1. 1. 0. 0. 0.]
# 100.0

# %%
index = 1 # change this to change image
images = np.load('Data/MVN_X.npy')
tensors = np.transpose(images,(0,3,1,2))
tensors = torch.from_numpy(tensors[index].reshape(1,3,256,256)).double()
with torch.no_grad():
    result = net(tensors.to(device))
    result = nn.Sigmoid()(result)
  #result = 1 if (result > 0.5) else 0
plt.imshow(images[index,:,:,::-1])
if(result > 0.5):
  print('these are notes ('+str(result.item()*100)+'% sure)')
else:
  print('its a meme ('+str((1-result.item())*100)+'% sure)')
# Out:
# these are notes (100.0% sure)
